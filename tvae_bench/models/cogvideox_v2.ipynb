# %%
import os
import torch
import imageio
import numpy as np
from torchvision import transforms
from typing import Tuple, List, Dict, Type
import logging

logging.getLogger('imageio_ffmpeg').setLevel(logging.ERROR)

# Configuration Class
class Config:
    def __init__(
        self,
        model_class: Type,
        model_path: str,
        device: str = "cuda",
        dtype: str = "float16",
        batch_size: int = 1,
        custom_batch_size: Dict[str, int] = None,
        source_base: str = "../resources/videos/",
        output_base: str = "./output_videos/"
    ):
        self.model_class = model_class
        self.model_path = model_path
        self.device = device
        self.dtype = torch.float16 if dtype == "float16" else torch.bfloat16
        self.batch_size = batch_size
        self.custom_batch_size = custom_batch_size or {}
        self.source_base = source_base
        self.output_base = output_base

# GeneralAutoEncoderKL Class
class GeneralAutoEncoderKL:
    def __init__(self, config: Config):
        self.config = config
        self.device = torch.device(self.config.device)
        self.dtype = self.config.dtype

        os.makedirs(self.config.output_base, exist_ok=True)

        self.model = self.config.model_class.from_pretrained(
            self.config.model_path,
            torch_dtype=self.dtype
        ).to(self.device)

        print(f"Model loaded successfully from {self.config.model_path}.")

        self.model.disable_slicing()
        self.model.disable_tiling()

        self.transform = transforms.ToTensor()

    def preprocess_videos(self, video_paths: List[str]) -> Tuple[torch.Tensor, List[float], List[int], List[Tuple[int, int]]]:
        batch_frames = []
        fps_list, num_frames_list, resolutions = [], [], []

        for video_path in video_paths:
            video_reader = imageio.get_reader(video_path, "ffmpeg")
            meta_data = video_reader.get_meta_data()
            fps = meta_data.get('fps', 30)

            frames = [self.transform(frame) for frame in video_reader]
            video_reader.close()

            if not frames:
                raise ValueError(f"No frames found in video: {video_path}")

            num_frames = len(frames)
            resolution = frames[0].shape[1], frames[0].shape[2]

            fps_list.append(fps)
            num_frames_list.append(num_frames)
            resolutions.append(resolution)

            frames_tensor = torch.stack(frames).to(self.device).permute(1, 0, 2, 3)
            batch_frames.append(frames_tensor)

        batch_tensor = torch.stack(batch_frames).to(self.dtype)
        return batch_tensor, fps_list, num_frames_list, resolutions

    def encode(self, frames_tensor: torch.Tensor) -> torch.Tensor:
        with torch.no_grad():
            encoded_frames = self.model.encode(frames_tensor)[0].sample()
        return encoded_frames

    def decode(self, encoded_tensor: torch.Tensor) -> torch.Tensor:
        with torch.no_grad():
            decoded_frames = self.model.decode(encoded_tensor).sample
        return decoded_frames

    def save_videos(self, tensor: torch.Tensor, output_paths: List[str], fps_list: List[float],
                    num_frames_list: List[int], resolutions: List[Tuple[int, int]]):
        tensor = tensor.to(dtype=torch.float32)
        for i, (fps, num_frames, resolution, output_path) in enumerate(zip(fps_list, num_frames_list, resolutions, output_paths)):
            frames = tensor[i].permute(1, 2, 3, 0).cpu().numpy()
            frames = np.clip(frames, 0, 1) * 255
            frames = frames.astype(np.uint8)

            num_output_frames = frames.shape[0]
            assert num_output_frames == num_frames, (
                f"Frame count mismatch: input {num_frames} vs output {num_output_frames}")

            output_resolution = frames.shape[1], frames.shape[2]
            assert output_resolution == resolution, (
                f"Resolution mismatch: input {resolution} vs output {output_resolution}")

            writer = imageio.get_writer(output_path, fps=fps, codec='libx264')
            for frame in frames:
                writer.append_data(frame)
            writer.close()

            print(f"Saved video to {output_path} with {num_output_frames} frames at {output_resolution} resolution and {fps} fps.")

    def reconstruct_videos(self, video_paths: List[str], output_paths: List[str]):
        batch_size = self.config.batch_size
        for dataset_name, custom_size in self.config.custom_batch_size.items():
            if any(dataset_name in path for path in video_paths):
                batch_size = custom_size
                break

        for i in range(0, len(video_paths), batch_size):
            batch_video_paths = video_paths[i:i + batch_size]
            batch_output_paths = output_paths[i:i + batch_size]

            frames_tensor, fps_list, num_frames_list, resolutions = self.preprocess_videos(batch_video_paths)
            encoded = self.encode(frames_tensor)
            decoded = self.decode(encoded)
            self.save_videos(decoded, batch_output_paths, fps_list, num_frames_list, resolutions)
            del frames_tensor, encoded, decoded

# %%
# * Testing code on H100 server
import os
import time
from datetime import datetime, timedelta

# Set Hugging Face home directory
os.environ["HF_HOME"] = "/jfs/jinjie/huggingface"
def format_timedelta(td):
    """Formats a timedelta object into HH:MM:SS string."""
    seconds = int(td.total_seconds())
    hours, remainder = divmod(seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    return f"{hours:02d}:{minutes:02d}:{seconds:02d}"



from diffusers import AutoencoderKLCogVideoX


# Processing Script
if __name__ == "__main__":
    
    
    data_root="/jfs/jinjie"
    
    
    config = Config(
        model_class=AutoencoderKLCogVideoX,
        # model_path="THUDM/CogVideoX-2b",
        model_path=f"{data_root}/huggingface/hub/models--THUDM--CogVideoX-2b/snapshots/1137dacfc2c9c012bed6a0793f4ecf2ca8e7ba01/vae",
        device="cuda:4",
        dtype="bfloat16", 
        batch_size=1,
        custom_batch_size={'imagenet_val': 1, 'textocr': 1, 'bridgedata_v2':1, 'panda_70m':1, 'real10k':1}, # * variable resolution
        source_base=f"{data_root}/data/vae_eval_bench/processed_gt_v3", 
        output_base=f"{data_root}/data/vae_eval_bench/model_recon/cogvideox_v2"
        # source_base="/mnt/data/jinjie/data/vae_eval_bench/processed_gt_v3",
        # output_base="/mnt/data/jinjie/data/vae_eval_bench/model_recon/cogvideox"
    )

    autoencoder = GeneralAutoEncoderKL(config)

    for dataset in os.listdir(config.source_base):

        dataset_source_path = os.path.join(config.source_base, dataset)
        dataset_output_path = os.path.join(config.output_base, dataset)

        if not os.path.isdir(dataset_source_path):
            continue

        print(f"Processing dataset: {dataset}")
        start_time = datetime.now()  # Start the timer
        
        os.makedirs(dataset_output_path, exist_ok=True)

        video_files = sorted([f for f in os.listdir(dataset_source_path) if f.endswith('.mp4')])
        video_paths = [os.path.join(dataset_source_path, f) for f in video_files]
        output_paths = [os.path.join(dataset_output_path, f) for f in video_files]

        autoencoder.reconstruct_videos(video_paths, output_paths)
        
        end_time = datetime.now()  # Stop the timer
        time_taken = end_time - start_time
        formatted_time = format_timedelta(time_taken)

        print(f"Finished processing {dataset}. Time taken: {formatted_time}")


    print("All datasets have been processed successfully.")
# Out:
# Model loaded successfully from /jfs/jinjie/huggingface/hub/models--THUDM--CogVideoX-2b/snapshots/1137dacfc2c9c012bed6a0793f4ecf2ca8e7ba01/vae.
# Processing dataset: BDD100K
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0000.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0001.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0002.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0003.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0004.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0005.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0006.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0007.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0008.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0009.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0010.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0011.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0012.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0013.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0014.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0015.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0016.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0017.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0018.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0019.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0020.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0021.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0022.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0023.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0024.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0025.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0026.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0027.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0028.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0029.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0030.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0031.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0032.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0033.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0034.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0035.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0036.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0037.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0038.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0039.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0040.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0041.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0042.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0043.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0044.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0045.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0046.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0047.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0048.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0049.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0050.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0051.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0052.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0053.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0054.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0055.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0056.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0057.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0058.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0059.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0060.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0061.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0062.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0063.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0064.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0065.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0066.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0067.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0068.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0069.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0070.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0071.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0072.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0073.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0074.mp4 with 105 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0075.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0076.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0077.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0078.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0079.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0080.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0081.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0082.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0083.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0084.mp4 with 105 frames at (720, 1280) resolution and 60.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0085.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0086.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0087.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0088.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0089.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0090.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0091.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0092.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0093.mp4 with 105 frames at (720, 1280) resolution and 60.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0094.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0095.mp4 with 105 frames at (720, 1280) resolution and 59.94 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0096.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0097.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0098.mp4 with 105 frames at (720, 1280) resolution and 29.92 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/BDD100K/0099.mp4 with 105 frames at (720, 1280) resolution and 29.97 fps.
# Finished processing BDD100K. Time taken: 00:47:56
# Processing dataset: bridgedata_v2
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0000.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0001.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0002.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0003.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0004.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0005.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0006.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0007.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0008.mp4 with 1 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0009.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0010.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0011.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0012.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0013.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0014.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0015.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0016.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0017.mp4 with 17 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0018.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0019.mp4 with 49 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0020.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0021.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0022.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0023.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0024.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0025.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0026.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0027.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0028.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0029.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0030.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0031.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0032.mp4 with 17 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0033.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0034.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0035.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0036.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0037.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0038.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0039.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0040.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0041.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0042.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0043.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0044.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0045.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0046.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0047.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0048.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0049.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0050.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0051.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0052.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0053.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0054.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0055.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0056.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0057.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0058.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0059.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0060.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0061.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0062.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0063.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0064.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0065.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0066.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0067.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0068.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0069.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0070.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0071.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0072.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0073.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0074.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0075.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0076.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0077.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0078.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0079.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0080.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0081.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0082.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0083.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0084.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0085.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0086.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0087.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0088.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0089.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0090.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0091.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0092.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0093.mp4 with 57 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0094.mp4 with 41 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0095.mp4 with 41 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0096.mp4 with 41 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0097.mp4 with 41 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0098.mp4 with 41 frames at (480, 640) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/bridgedata_v2/0099.mp4 with 41 frames at (480, 640) resolution and 30.0 fps.
# Finished processing bridgedata_v2. Time taken: 00:11:38
# Processing dataset: dynamic_replica
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0000.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0001.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0002.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0003.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0004.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0005.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0006.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0007.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0008.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0009.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0010.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0011.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0012.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0013.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0014.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0015.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0016.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0017.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0018.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0019.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0020.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0021.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0022.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0023.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0024.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0025.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0026.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0027.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0028.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0029.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0030.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0031.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0032.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0033.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0034.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0035.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0036.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0037.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0038.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0039.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0040.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0041.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0042.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0043.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0044.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0045.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0046.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0047.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0048.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0049.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0050.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0051.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0052.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0053.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0054.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0055.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0056.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0057.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0058.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0059.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0060.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0061.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0062.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0063.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0064.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0065.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0066.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0067.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0068.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0069.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0070.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0071.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0072.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0073.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0074.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0075.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0076.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0077.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0078.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0079.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0080.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0081.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0082.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0083.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0084.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0085.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0086.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0087.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0088.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0089.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0090.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0091.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0092.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0093.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0094.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0095.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0096.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0097.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0098.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/dynamic_replica/0099.mp4 with 97 frames at (720, 1280) resolution and 30.0 fps.
# Finished processing dynamic_replica. Time taken: 00:44:56
# Processing dataset: ego-exo-4d-ego
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0000.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0002.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0004.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0013.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0015.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0017.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0019.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0021.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0023.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0025.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0030.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0034.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0037.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0039.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0041.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0044.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0046.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0048.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/ego-exo-4d-ego/0050.mp4 with 105 frames at (448, 448) resolution and 30.0 fps.
# ...
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0085.mp4 with 1 frames at (368, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0086.mp4 with 1 frames at (352, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0087.mp4 with 1 frames at (352, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0088.mp4 with 1 frames at (352, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0089.mp4 with 1 frames at (352, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0090.mp4 with 1 frames at (400, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0091.mp4 with 1 frames at (512, 400) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0092.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0093.mp4 with 1 frames at (464, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0094.mp4 with 1 frames at (448, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0095.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0096.mp4 with 1 frames at (480, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0097.mp4 with 1 frames at (512, 496) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0098.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0099.mp4 with 1 frames at (400, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0100.mp4 with 1 frames at (512, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0101.mp4 with 1 frames at (464, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0102.mp4 with 1 frames at (512, 400) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0103.mp4 with 1 frames at (416, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0104.mp4 with 1 frames at (512, 416) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0105.mp4 with 1 frames at (400, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0106.mp4 with 1 frames at (512, 384) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0107.mp4 with 1 frames at (400, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0108.mp4 with 1 frames at (512, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0109.mp4 with 1 frames at (416, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0110.mp4 with 1 frames at (512, 416) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0111.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0112.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0113.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0114.mp4 with 1 frames at (448, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0115.mp4 with 1 frames at (448, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0116.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0117.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0118.mp4 with 1 frames at (512, 384) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0119.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0120.mp4 with 1 frames at (336, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0121.mp4 with 1 frames at (384, 512) resolution and 30.0 fps.
# Saved video to /jfs/jinjie/data/vae_eval_bench/model_recon/cogvideox_v2/imagenet_val/0122.mp4 with 1 frames at (480, 720) resolution and 30.0 fps.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 60
#      57 video_paths = [os.path.join(dataset_source_path, f) for f in video_files]
#      58 output_paths = [os.path.join(dataset_output_path, f) for f in video_files]
# ---> 60 autoencoder.reconstruct_videos(video_paths, output_paths)
#      62 end_time = datetime.now()  # Stop the timer
#      63 time_taken = end_time - start_time
#
# Cell In[1], line 128, in GeneralAutoEncoderKL.reconstruct_videos(self, video_paths, output_paths)
#     126 frames_tensor, fps_list, num_frames_list, resolutions = self.preprocess_videos(batch_video_paths)
#     127 encoded = self.encode(frames_tensor)
# --> 128 decoded = self.decode(encoded)
#     129 self.save_videos(decoded, batch_output_paths, fps_list, num_frames_list, resolutions)
#     130 del frames_tensor, encoded, decoded
#
# Cell In[1], line 89, in GeneralAutoEncoderKL.decode(self, encoded_tensor)
#      87 def decode(self, encoded_tensor: torch.Tensor) -> torch.Tensor:
#      88     with torch.no_grad():
# ---> 89         decoded_frames = self.model.decode(encoded_tensor).sample
#      90     return decoded_frames
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/diffusers/utils/accelerate_utils.py:46, in apply_forward_hook.<locals>.wrapper(self, *args, **kwargs)
#      44 if hasattr(self, "_hf_hook") and hasattr(self._hf_hook, "pre_forward"):
#      45     self._hf_hook.pre_forward(self)
# ---> 46 return method(self, *args, **kwargs)
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/diffusers/models/autoencoders/autoencoder_kl_cogvideox.py:1287, in AutoencoderKLCogVideoX.decode(self, z, return_dict)
#    1285     decoded = torch.cat(decoded_slices)
#    1286 else:
# -> 1287     decoded = self._decode(z).sample
#    1289 if not return_dict:
#    1290     return (decoded,)
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/diffusers/models/autoencoders/autoencoder_kl_cogvideox.py:1258, in AutoencoderKLCogVideoX._decode(self, z, return_dict)
#    1256     if self.post_quant_conv is not None:
#    1257         z_intermediate = self.post_quant_conv(z_intermediate)
# -> 1258     z_intermediate, conv_cache = self.decoder(z_intermediate, conv_cache=conv_cache)
#    1259     dec.append(z_intermediate)
#    1261 dec = torch.cat(dec, dim=2)
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/diffusers/models/autoencoders/autoencoder_kl_cogvideox.py:978, in CogVideoXDecoder3D.forward(self, sample, temb, conv_cache)
#     976     for i, up_block in enumerate(self.up_blocks):
#     977         conv_cache_key = f"up_block_{i}"
# --> 978         hidden_states, new_conv_cache[conv_cache_key] = up_block(
#     979             hidden_states, temb, sample, conv_cache=conv_cache.get(conv_cache_key)
#     980         )
#     982 # 3. Post-process
#     983 hidden_states, new_conv_cache["norm_out"] = self.norm_out(
#     984     hidden_states, sample, conv_cache=conv_cache.get("norm_out")
#     985 )
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/diffusers/models/autoencoders/autoencoder_kl_cogvideox.py:655, in CogVideoXUpBlock3D.forward(self, hidden_states, temb, zq, conv_cache)
#     647         hidden_states, new_conv_cache[conv_cache_key] = torch.utils.checkpoint.checkpoint(
#     648             create_custom_forward(resnet),
#     649             hidden_states,
#    (...)
#     652             conv_cache.get(conv_cache_key),
#     653         )
#     654     else:
# --> 655         hidden_states, new_conv_cache[conv_cache_key] = resnet(
#     656             hidden_states, temb, zq, conv_cache=conv_cache.get(conv_cache_key)
#     657         )
#     659 if self.upsamplers is not None:
#     660     for upsampler in self.upsamplers:
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/diffusers/models/autoencoders/autoencoder_kl_cogvideox.py:304, in CogVideoXResnetBlock3D.forward(self, inputs, temb, zq, conv_cache)
#     301     hidden_states = self.norm1(hidden_states)
#     303 hidden_states = self.nonlinearity(hidden_states)
# --> 304 hidden_states, new_conv_cache["conv1"] = self.conv1(hidden_states, conv_cache=conv_cache.get("conv1"))
#     306 if temb is not None:
#     307     hidden_states = hidden_states + self.temb_proj(self.nonlinearity(temb))[:, :, None, None, None]
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/diffusers/models/autoencoders/autoencoder_kl_cogvideox.py:144, in CogVideoXCausalConv3d.forward(self, inputs, conv_cache)
#     141     conv_cache = inputs[:, :, -self.time_kernel_size + 1 :].clone()
#     142     inputs = F.pad(inputs, padding_2d, mode="constant", value=0)
# --> 144 output = self.conv(inputs)
#     145 return output, conv_cache
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/diffusers/models/autoencoders/autoencoder_kl_cogvideox.py:62, in CogVideoXSafeConv3d.forward(self, input)
#      60 output_chunks = []
#      61 for input_chunk in input_chunks:
# ---> 62     output_chunks.append(super().forward(input_chunk))
#      63 output = torch.cat(output_chunks, dim=2)
#      64 return output
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/conv.py:610, in Conv3d.forward(self, input)
#     609 def forward(self, input: Tensor) -> Tensor:
# --> 610     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/conda/envs/sora/lib/python3.11/site-packages/torch/nn/modules/conv.py:605, in Conv3d._conv_forward(self, input, weight, bias)
#     593 if self.padding_mode != "zeros":
#     594     return F.conv3d(
#     595         F.pad(
#     596             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     603         self.groups,
#     604     )
# --> 605 return F.conv3d(
#     606     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     607 )
#
# RuntimeError: Calculated padded input size per channel: (2 x 1298 x 1602). Kernel size: (3 x 3 x 3). Kernel size can't be greater than actual input size

# %%
# * Testing code on V100 server
from diffusers import AutoencoderKLCogVideoX


# Processing Script
if __name__ == "__main__":
    config = Config(
        model_class=AutoencoderKLCogVideoX,
        # model_path="THUDM/CogVideoX-2b",
        model_path="/home/maij/.cache/huggingface/hub/models--THUDM--CogVideoX-5b/snapshots/8d6ea3f817438460b25595a120f109b88d5fdfad/vae",
        device="cuda:0",
        dtype="float16", # TODO: testing on bloat16
        batch_size=4,
        custom_batch_size={'imagenet_val': 1, 'textocr': 1, 'bridgedata_v2':1, 'panda_70m':1}, # * variable resolution
        source_base="/home/maij/fall_2024/sora3r/Open-Sora/data/vae_eval_bench/processed_gt_v3", 
        output_base="/home/maij/fall_2024/sora3r/Open-Sora/data/vae_eval_bench/model_recon/cogvideox"
        # source_base="/mnt/data/jinjie/data/vae_eval_bench/processed_gt_v3",
        # output_base="/mnt/data/jinjie/data/vae_eval_bench/model_recon/cogvideox"
    )

    autoencoder = GeneralAutoEncoderKL(config)

    for dataset in os.listdir(config.source_base):
        if dataset in ['BDD100K','bridgedata_v2','imagenet_val','objaverse','ego-exo-4d-ego','dynamic_replica','textocr']:
            continue
        dataset_source_path = os.path.join(config.source_base, dataset)
        dataset_output_path = os.path.join(config.output_base, dataset)

        if not os.path.isdir(dataset_source_path):
            continue

        print(f"Processing dataset: {dataset}")
        os.makedirs(dataset_output_path, exist_ok=True)

        video_files = sorted([f for f in os.listdir(dataset_source_path) if f.endswith('.mp4')])
        video_paths = [os.path.join(dataset_source_path, f) for f in video_files]
        output_paths = [os.path.join(dataset_output_path, f) for f in video_files]

        autoencoder.reconstruct_videos(video_paths, output_paths)

    print("All datasets have been processed successfully.")

# %%
# Processing Script Outside the CogVideoX Class
# This script iterates through each dataset folder and processes the videos accordingly.

# Initialize configuration
config = Config(
    model_path="/home/maij/.cache/huggingface/hub/models--THUDM--CogVideoX-5b/snapshots/8d6ea3f817438460b25595a120f109b88d5fdfad/vae",  # Replace with your actual model path
    device="cuda:1",  # or "cpu"
    # TODO : we should report bfloat16 result, on v100 test we use fp16 for now
    dtype="float16",  # or "bfloat16"
    source_base="/home/maij/fall_2024/sora3r/Open-Sora/data/vae_eval_bench/processed_gt_v2",  # Replace with your actual source base folder path
    output_base="/home/maij/fall_2024/sora3r/Open-Sora/data/vae_eval_bench/model_recon/cogvideox"  # Replace with your desired output base folder path
)

# Initialize CogVideoX
cog_video = CogVideoX(config)

# Iterate through each dataset folder in the source base directory
for dataset in os.listdir(config.source_base):
    dataset_source_path = os.path.join(config.source_base, dataset)
    dataset_output_path = os.path.join(config.output_base, dataset)
    
    # Check if it's a directory
    if not os.path.isdir(dataset_source_path):
        continue  # Skip if not a directory
    
    print(f"Processing dataset: {dataset}")
    
    # Ensure the output dataset directory exists
    os.makedirs(dataset_output_path, exist_ok=True)
    
    # Reconstruct all videos in the current dataset folder
    cog_video.reconstruct_folder_videos(dataset_source_path, dataset_output_path)
    
print("All datasets have been processed successfully.")

# %%
# * configuration on A100 node

# THUDM/CogVideoX-2b

# Processing Script Outside the CogVideoX Class
# This script iterates through each dataset folder and processes the videos accordingly.

# Initialize configuration
config = Config(
    model_path="THUDM/CogVideoX-2b",  # Replace with your actual model path
    device="cuda:0",  # or "cpu"
    dtype="bfloat16",  # or "bfloat16"
    source_base="/mnt/data/jinjie/data/vae_eval_bench/processed_gt_v2",  # Replace with your actual source base folder path
    output_base="/mnt/data/jinjie/data/vae_eval_bench/model_recon/cogvideox"  # Replace with your desired output base folder path
)

# Initialize CogVideoX
cog_video = CogVideoX(config)

# Iterate through each dataset folder in the source base directory
for dataset in os.listdir(config.source_base):
    dataset_source_path = os.path.join(config.source_base, dataset)
    dataset_output_path = os.path.join(config.output_base, dataset)
    
    # Check if it's a directory
    if not os.path.isdir(dataset_source_path):
        continue  # Skip if not a directory
    
    print(f"Processing dataset: {dataset}")
    
    # Ensure the output dataset directory exists
    os.makedirs(dataset_output_path, exist_ok=True)
    
    # Reconstruct all videos in the current dataset folder
    cog_video.reconstruct_folder_videos(dataset_source_path, dataset_output_path)
    
print("All datasets have been processed successfully.")
